# %% [markdown]
# # Stock Check Lambda Speed Solutions

# %%
import kafka

import pprint

from IPython.display import clear_output

import time

# %% [markdown]
# ## You try it -
#
# ## Modify stock_check_process to stream to the stock_check_stream topic; create a new jupyter notebook stock_check_lambda_speed to subscribe to stock_check_stream in streaming mode; solutions can be found in stock_check_process_solutions and stock_check_lambda_speed_solutions

# %%
topic = "stock_check_stream"

stream = kafka.KafkaConsumer(topic, 
                             bootstrap_servers=['kafka:29092'], 
                             auto_offset_reset='earliest')

# %%
i = 0

for message in stream:
    
    if i == 10:
        i = 0
        clear_output(wait=True)            
        print("\n=======================================")
        print("   Stock Check Lambda Speed Process")
        print("=======================================\n")
        print("\nClearing the screen every 10 objects to prevent running out of output space ...\n")
        

    
    print("Offset:", message.offset, "   Value:", message.value[:75])
    
    i += 1
